# %% [markdown]
# # Reading multiple data files

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 기본적으로 read_csv()로 파일을 dataframe으로 불러옴.
# pandas는 50가지 정도의 파라미터 옵션이 있음. 
# 그외에도 excel, html, json 을 지원

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# loop로 데이터를 불러오는 방법도 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# comprehension을 쓰면 좀더 명확

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# glob함수를 쓰면 많은 양의 데이터파일을 불러올 수 있음.
# sales로 시작하는 모든 csv파일을 가져온다는 의미임.
